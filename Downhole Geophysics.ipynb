# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
# %matplotlib inline

# %%
geo = pd.read_csv('./data/Complete_Geophysics.csv')

# %%
hole = geo.query('HOLEID == "DD0509"')

# %%
hole.columns
# Out:
# Index([u'HOLEID', u'PROJECTCODE', u'DEPTHSTEP', u'RUN', u'PRIORITY', u'DEPTH',
#        u'ADEN', u'AUCS', u'AVOL', u'AXLE', u'AXLN', u'AZID', u'AZIF', u'AZP1',
#        u'BBRG', u'BISI', u'BRAD', u'BRDU', u'BRG1', u'BRG2', u'BRG3', u'BRG4',
#        u'CADE', u'CALD', u'CODE', u'CORF', u'DECR', u'DENB', u'DENL', u'DEPO',
#        u'DIPF', u'FE1', u'FE1C', u'FE1U', u'FE2', u'FMAG', u'GRDE', u'GRNP',
#        u'HVOL', u'LSDU', u'LSN', u'MC2A', u'MC2F', u'MC2U', u'MC4F', u'MC6F',
#        u'MCUF', u'MDTC', u'MSAL', u'P1F', u'P2F', u'P3F', u'PCH1', u'RAD1',
#        u'RAD2', u'RAD3', u'RAD4', u'RPOR', u'SPOR', u'SSN', u'TDEP', u'TDIF',
#        u'TEMP', u'TILD', u'UCS', u'UCSM', u'VDEN', u'VL2A', u'VL2F', u'VL4F',
#        u'VL6F', u'VLUF', u'UCSD', u'TILF', u'MC2F_us_ft_DF', u'GRFE', u'DTCA',
#        u'DTCB', u'DTCC', u'DTCD', u'DTCE', u'DTCF'],
#       dtype='object')

# %%
subset = hole[['DENB','DENL','GRDE', 'LSDU', 'DEPTH']].sort('DEPTH')

# %%
subset.plot(x='DEPTH',y=['DENB','DENL','GRDE','LSDU'],figsize=(50,10))
